# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_excel('Schools Data.xlsx')

# %%
df
# Out:
#       Unnamed: 0     ID                 region  \
# 0              0      1    Акмолинская область
# 1              1      2    Акмолинская область
# 2              2      3    Акмолинская область
# 3              3      4    Акмолинская область
# 4              4      5    Акмолинская область
# ...          ...    ...                    ...
# 6059        6059  96713  Туркестанская область
# 6060        6060  97100  Туркестанская область
# 6061        6061  97197  Туркестанская область
# 6062        6062  97231  Туркестанская область
# 6063        6063  97553  Туркестанская область
#
#                                             school_type  total_students_2018  \
# 0     общеобразовательная школа, опорная школа (ресу...                  833
# 1                             общеобразовательная школа                  528
# 2     общеобразовательная школа, интернат при общеоб...                  714
# 3                             общеобразовательная школа                  354
# ...

# %%
for c in df.columns:
    print(c)
# Out:
# Unnamed: 0
# ID
# region
# school_type
# total_students_2018
# total_after_9_2018
# total_after_11_2018
# diff_teens_2018
# deficit_places_2018
# 3_times_school_2018
# barrier_free_2018
# stud_have_book_count_2018
# ip_higher_4mb_2018
# poor_fams_2018
# poor_fams_food_2018
# dorms_for_villages_2018
# total_teachers_2018
# teachers_1_category_2018
# higher_edu_teachers_2017
# master_teachers
# out_of_system_teachers_2018
# in_emergency_2018
# need_repair_2018
# school_city_dist
# only_out_toilet_2018
# school_density_in_10km
# school_density_in_3km
# school_density_in1.5km
# out_in_toilets_2018
# total_comp_2018
# interactive_boards_2017
# cameras__2017
# messa_2018
# sport_stud
# art_stud
# appl_art_stud
# technical_stud
# soc_student
# bio_eco_stud
# tourist_stud
# nat_math_stud
# lang_stud
# other_stud
# add_edu_stud
# high_category_teachers_2018
# eng_informatics_teachers
# eng_phys_teachers
# eng_chem_teachers
# eng_bio_teachers
# location
# tip_organizacii_obrazovaniya
# ...

# %%
df_GPD = pd.read_excel('GDP by region.xlsx')

# %%
df_GPD
# Out:
#                        Адм.единица       2017 % от страны
# 0                         г.Алматы  8741885.2       20.3%
# 1               Атырауская область  5442058.4       12.6%
# 2                         г.Астана  4637688.4       10.8%
# 3           Карагандинская область  3413949.2        7.9%
# 4            Туркестанская область  2680982.2        6.2%
# 5   Восточно-Казахстанская область  2506248.0        5.8%
# 6            Мангистауская область  2231986.2        5.2%
# 7              Алматинская область  1890574.4        4.4%
# 8    Западно-Казахстанская область  1979439.4        4.6%
# 9              Актюбинская область  1991774.4        4.6%
# 10            Павлодарская область  2030709.6        4.7%
# 11            Костанайская область  1379214.0        3.2%
# 12             Акмолинская область  1110777.4        2.6%
# 13          Кызылординская область  1301573.2        3.0%
# 14              Жамбылская область  1056955.0        2.5%
# ...

# %%
df_GPD.columns = ['region', 'VVP','%_of_contry' ]

# %%
df_GPD
# Out:
#                             region        VVP %_of_contry
# 0                         г.Алматы  8741885.2       20.3%
# 1               Атырауская область  5442058.4       12.6%
# 2                         г.Астана  4637688.4       10.8%
# 3           Карагандинская область  3413949.2        7.9%
# 4            Туркестанская область  2680982.2        6.2%
# 5   Восточно-Казахстанская область  2506248.0        5.8%
# 6            Мангистауская область  2231986.2        5.2%
# 7              Алматинская область  1890574.4        4.4%
# 8    Западно-Казахстанская область  1979439.4        4.6%
# 9              Актюбинская область  1991774.4        4.6%
# 10            Павлодарская область  2030709.6        4.7%
# 11            Костанайская область  1379214.0        3.2%
# 12             Акмолинская область  1110777.4        2.6%
# 13          Кызылординская область  1301573.2        3.0%
# 14              Жамбылская область  1056955.0        2.5%
# ...

# %%
df['region'].unique()
# Out:
# array(['Акмолинская область', 'Актюбинская область',
#        'Алматинская область', 'Атырауская область',
#        'Восточно-Казахстанская область', 'г.Алматы', 'г.Астана',
#        'г.Шымкент', 'Жамбылская область', 'Западно-Казахстанская область',
#        'Карагандинская область', 'Костанайская область',
#        'Кызылординская область', 'Мангистауская область',
#        'Павлодарская область', 'Северо-Казахстанская область',
#        'Туркестанская область'], dtype=object)

# %%
df_GPD['region'].unique()
# Out:
# array(['г.Алматы', 'Атырауская область', 'г.Астана',
#        'Карагандинская область', 'Туркестанская область',
#        'Восточно-Казахстанская область', 'Мангистауская область',
#        'Алматинская область', 'Западно-Казахстанская область',
#        'Актюбинская область', 'Павлодарская область',
#        'Костанайская область', 'Акмолинская область',
#        'Кызылординская область', 'Жамбылская область',
#        'Северо-Казахстанская область'], dtype=object)

# %%
df_join = pd.merge(df, df_GPD, on = ['region'], how = 'outer')
df_join
# Out:
#       Unnamed: 0     ID                 region  \
# 0              0      1    Акмолинская область
# 1              1      2    Акмолинская область
# 2              2      3    Акмолинская область
# 3              3      4    Акмолинская область
# 4              4      5    Акмолинская область
# ...          ...    ...                    ...
# 6059        6059  96713  Туркестанская область
# 6060        6060  97100  Туркестанская область
# 6061        6061  97197  Туркестанская область
# 6062        6062  97231  Туркестанская область
# 6063        6063  97553  Туркестанская область
#
#                                             school_type  total_students_2018  \
# 0     общеобразовательная школа, опорная школа (ресу...                  833
# 1                             общеобразовательная школа                  528
# 2     общеобразовательная школа, интернат при общеоб...                  714
# 3                             общеобразовательная школа                  354
# ...

# %%
df_join.dtypes
# Out:
# Unnamed: 0                    int64
# ID                            int64
# region                       object
# school_type                  object
# total_students_2018           int64
#                              ...
# qedu_passed_ent             float64
# qedu_continued_education    float64
# qedu_elite_achievements     float64
# VVP                         float64
# %_of_contry                  object
# Length: 214, dtype: object

# %%
df_join.fillna(0)
# Out:
#       Unnamed: 0     ID                 region  \
# 0              0      1    Акмолинская область
# 1              1      2    Акмолинская область
# 2              2      3    Акмолинская область
# 3              3      4    Акмолинская область
# 4              4      5    Акмолинская область
# ...          ...    ...                    ...
# 6059        6059  96713  Туркестанская область
# 6060        6060  97100  Туркестанская область
# 6061        6061  97197  Туркестанская область
# 6062        6062  97231  Туркестанская область
# 6063        6063  97553  Туркестанская область
#
#                                             school_type  total_students_2018  \
# 0     общеобразовательная школа, опорная школа (ресу...                  833
# 1                             общеобразовательная школа                  528
# 2     общеобразовательная школа, интернат при общеоб...                  714
# 3                             общеобразовательная школа                  354
# ...

# %%
#1
for region in df_join['region'].unique():
    df_join_r = df_join[df_join['region'] == region]
    print(region)
    df_join_r.to_excel(region + '.xlsx')
# Out:
# Акмолинская область
# Актюбинская область
# Алматинская область
# Атырауская область
# Восточно-Казахстанская область
# г.Алматы
# г.Астана
# г.Шымкент
# Жамбылская область
# Западно-Казахстанская область
# Карагандинская область
# Костанайская область
# Кызылординская область
# Мангистауская область
# Павлодарская область
# Северо-Казахстанская область
# Туркестанская область

# %%
df_black=df_join[df_join['qedu_passed_ent'] < 0.5]
df_black
# Out:
#       Unnamed: 0     ID                 region  \
# 52            52     58    Акмолинская область
# 119          119    136    Акмолинская область
# 129          129    146    Акмолинская область
# 149          149    173    Акмолинская область
# 314          314    424    Акмолинская область
# ...          ...    ...                    ...
# 5920        5920   5702  Туркестанская область
# 5925        5925   5708  Туркестанская область
# 5947        5947   5746  Туркестанская область
# 6061        6061  97197  Туркестанская область
# 6062        6062  97231  Туркестанская область
#
#                                            school_type  total_students_2018  \
# 52    общеобразовательная школа, малокомплектная школа                  166
# 119                          общеобразовательная школа                  255
# 129   общеобразовательная школа, малокомплектная школа                   64
# 149   общеобразовательная школа, малокомплектная школа                  108
# ...

# %%
#2
for region in df_black['region'].unique():
    df_black_r = df_black[df_black['region'] == region]
    print(region)
    df_black_r.to_excel(region + 'черныйсписок.xlsx')
# Out:
# Акмолинская область
# Актюбинская область
# Алматинская область
# Атырауская область
# Восточно-Казахстанская область
# г.Астана
# Жамбылская область
# Западно-Казахстанская область
# Карагандинская область
# Костанайская область
# Мангистауская область
# Павлодарская область
# Северо-Казахстанская область
# Туркестанская область

# %%
df_repair=df_join[df_join['need_repair_2018'] == 1]
df_repair
# Out:
#       Unnamed: 0     ID                 region  \
# 8              8      9    Акмолинская область
# 14            14     15    Акмолинская область
# 25            25     28    Акмолинская область
# 54            54     60    Акмолинская область
# 58            58     65    Акмолинская область
# ...          ...    ...                    ...
# 5955        5955   5768  Туркестанская область
# 5960        5960   5773  Туркестанская область
# 5964        5964   5777  Туркестанская область
# 6023        6023  81084  Туркестанская область
# 6036        6036  81771  Туркестанская область
#
#                                            school_type  total_students_2018  \
# 8     общеобразовательная школа, малокомплектная школа                  126
# 14    общеобразовательная школа, малокомплектная школа                  131
# 25              начальная школа, малокомплектная школа                   14
# 54    общеобразовательная школа, малокомплектная школа                  125
# ...

# %%
df_toilet=df_join[df_join['only_out_toilet_2018'] == 1]
df_toilet
# Out:
#       Unnamed: 0     ID                 region  \
# 126          126    143    Акмолинская область
# 307          307    416    Акмолинская область
# 492          492   1272    Актюбинская область
# 494          494   1274    Актюбинская область
# 495          495   1275    Актюбинская область
# ...          ...    ...                    ...
# 6048        6048  85321  Туркестанская область
# 6049        6049  90785  Туркестанская область
# 6052        6052  91142  Туркестанская область
# 6056        6056  95367  Туркестанская область
# 6061        6061  97197  Туркестанская область
#
#                                         school_type  total_students_2018  \
# 126   основная средняя школа, малокомплектная школа                   30
# 307          начальная школа, малокомплектная школа                    5
# 492   основная средняя школа, малокомплектная школа                   63
# 494   основная средняя школа, малокомплектная школа                   39
# ...

# %%
#df_food=df_join[df_join['#######'] == 1]
#df_food

# %%
df_join['eng_informatics_teachers'][df_join['eng_informatics_teachers'] >0].plot(kind='hist')
df_join['eng_bio_teachers'][df_join['eng_bio_teachers'] >0].plot(kind='hist')
df_join['eng_phys_teachers'][df_join['eng_phys_teachers'] >0].plot(kind='hist')
df_join['eng_chem_teachers'][df_join['eng_chem_teachers'] >0].plot(kind='hist')

# %%
df_join['eng_bio_teachers'][df_join['eng_bio_teachers'] >0].plot(kind='hist')

# %%
df_ENGinf=df_join[df_join['eng_informatics_teachers'] > 0]
df_enginfsort=df_ENGinf.sort_values('eng_informatics_teachers',ascending=False)

# %%
 df_enginfsort
# Out:
#       Unnamed: 0     ID                 region  \
# 5488        5488   2794  Туркестанская область
# 2374        2374   1573               г.Алматы
# 4594        4594  80526  Мангистауская область
# 2735        2735   1891     Жамбылская область
# 2729        2729   1885     Жамбылская область
# ...          ...    ...                    ...
# 2306        2306   1490               г.Алматы
# 2305        2305   1489               г.Алматы
# 2303        2303   1487               г.Алматы
# 2301        2301   1485               г.Алматы
# 2933        2933  80689     Жамбылская область
#
#                                             school_type  total_students_2018  \
# 5488                          общеобразовательная школа                  876
# 2374  специализированная гимназия (специализированны...                 1884
# 4594                          общеобразовательная школа                 2304
# 2735                          общеобразовательная школа                 1404
# ...

# %%
df_ENGphy=df_join[df_join['eng_phys_teachers'] > 0]
df_engphysort=df_ENGphy.sort_values('eng_phys_teachers',ascending=False)

# %%
df_engphysort
# Out:
#       Unnamed: 0     ID                         region  \
# 2957        2957   3258  Западно-Казахстанская область
# 2374        2374   1573                       г.Алматы
# 2735        2735   1891             Жамбылская область
# 4558        4558  80433          Мангистауская область
# 4402        4402   6597         Кызылординская область
# ...          ...    ...                            ...
# 2292        2292   1120                       г.Алматы
# 2291        2291   1118                       г.Алматы
# 2286        2286   1073                       г.Алматы
# 2283        2283   1058                       г.Алматы
# 6058        6058  96399          Туркестанская область
#
#                                             school_type  total_students_2018  \
# 2957          общеобразовательная школа, школа-гимназия                 1926
# 2374  специализированная гимназия (специализированны...                 1884
# ...

# %%
df_ENGchem=df_join[df_join['eng_chem_teachers'] > 0]
df_engchemsort=df_ENGchem.sort_values('eng_chem_teachers',ascending=False)

# %%
df_engchemsort
# Out:
#       Unnamed: 0     ID                         region  \
# 3164        3164   4127  Западно-Казахстанская область
# 3196        3196   4239  Западно-Казахстанская область
# 2872        2872   2084             Жамбылская область
# 4398        4398   6593         Кызылординская область
# 5469        5469   2590          Туркестанская область
# ...          ...    ...                            ...
# 2313        2313   1497                       г.Алматы
# 2323        2323   1507                       г.Алматы
# 2324        2324   1508                       г.Алматы
# 2332        2332   1516                       г.Алматы
# 6061        6061  97197          Туркестанская область
#
#                                     school_type  total_students_2018  \
# 3164                  общеобразовательная школа                 2828
# 3196                  общеобразовательная школа                 1528
# 2872                  общеобразовательная школа                  440
# ...

# %%
df_ENGbio=df_join[df_join['eng_bio_teachers'] > 0]
df_engbiosort=df_ENGbio.sort_values('eng_bio_teachers',ascending=False)

# %%
df_engbiosort
# Out:
#       Unnamed: 0     ID                         region  \
# 2730        2730   1886             Жамбылская область
# 2486        2486   4407                       г.Астана
# 2835        2835   2021             Жамбылская область
# 2728        2728   1884             Жамбылская область
# 3056        3056   3808  Западно-Казахстанская область
# ...          ...    ...                            ...
# 2294        2294   1478                       г.Алматы
# 2291        2291   1118                       г.Алматы
# 2290        2290   1089                       г.Алматы
# 2288        2288   1083                       г.Алматы
# 6054        6054  93033          Туркестанская область
#
#                                     school_type  total_students_2018  \
# 2730                  общеобразовательная школа                 1812
# 2486     общеобразовательная школа, школа-лицей                 1368
# 2835     общеобразовательная школа, школа-лицей                  942
# ...

# %%
df_TOP_eng = df_join.sort_values(by=['eng_informatics_teachers', 'eng_phys_teachers', 'eng_chem_teachers', 'eng_bio_teachers'],ascending=False)

# %%
df_TOP_eng.to_excel('TOPENGLISH.xlsx')

# %%
df_TOP_eng.head()
# Out:
#       Unnamed: 0    ID                 region  \
# 2735        2735  1891     Жамбылская область
# 2374        2374  1573               г.Алматы
# 2729        2729  1885     Жамбылская область
# 2361        2361  1559               г.Алматы
# 5488        5488  2794  Туркестанская область
#
#                                             school_type  total_students_2018  \
# 2735                          общеобразовательная школа                 1404
# 2374  специализированная гимназия (специализированны...                 1884
# 2729                общеобразовательная школа, гимназия                 1937
# 2361                общеобразовательная школа, гимназия                 1620
# 5488                          общеобразовательная школа                  876
#
#       total_after_9_2018  total_after_11_2018  diff_teens_2018  \
# 2735                 112                 62.0              0.0
# 2374                 149                103.0              0.0
# ...
